# %% [markdown]
# ## Day 2 of Data Workshop Challenge

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(1, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1);
plt.plot(x, y2);
